# %%
# %run dataPrep.py cis-4496-project-hvac/Sample_Data/Raw/touchcombo_00915540.csv
# Out:
# Processed file saved to: cis-4496-project-hvac/Sample_Data/Processed/touchcombo_00915540.csv

# %%
for i in range(1, 101):  # 1 through 40
    filename = f"cis-4496-project-hvac/Sample_Data/Raw/timeseries_table_timeseries_table ({i}).csv"
    print(f"Running dataPrep.py on {filename}")
    # %run dataPrep.py "{filename}"
# Out:
# Running dataPrep.py on cis-4496-project-hvac/Sample_Data/Raw/timeseries_table_timeseries_table (1).csv
# Processed file saved to: cis-4496-project-hvac/Sample_Data/Processed/timeseries_table_timeseries_table (1).csv
# Running dataPrep.py on cis-4496-project-hvac/Sample_Data/Raw/timeseries_table_timeseries_table (2).csv
# Processed file saved to: cis-4496-project-hvac/Sample_Data/Processed/timeseries_table_timeseries_table (2).csv
# Running dataPrep.py on cis-4496-project-hvac/Sample_Data/Raw/timeseries_table_timeseries_table (3).csv
# Processed file saved to: cis-4496-project-hvac/Sample_Data/Processed/timeseries_table_timeseries_table (3).csv
# Running dataPrep.py on cis-4496-project-hvac/Sample_Data/Raw/timeseries_table_timeseries_table (4).csv
# /Users/laurensobieski/capstone/dataPrep.py:6: DtypeWarning: Columns (0: RentalStatus) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(
# ...
